# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import os

# %%
df = pd.read_csv('dataTweet/TweetsTrendingEc-8Julio21.csv', sep=';',encoding='utf-8')
df
# Out:
#      Unnamed: 0                fecha  \
# 0             1  2021-07-07 19:22:13
# 1             2  2021-07-08 05:57:28
# 2             3  2021-07-08 09:05:40
# 3             4  2021-07-08 05:47:18
# 4             5  2021-07-08 02:40:00
# ..          ...                  ...
# 533          14  2021-07-04 18:35:29
# 534          15  2021-07-08 17:15:56
# 535           1  2021-07-08 16:38:59
# 536           2  2021-07-08 16:12:02
# 537           3  2021-07-08 16:25:43
#
#                                                  texto  retweets  favoritos  \
# 0    Tuliwaambia wamejazama CCM bungeni hakuna kitu...       201       1177
# 1    "There’s no reason for me to be President when...        67        367
# 2    Nadhani sasa kila mmoja amerudi kwenye factory...        77        642
# 3    "In other countries you have kickbacks of 10%....        17         97
# 4    Kitu gani kinajiri ulipo ? Tufahamishane @Vinc...        17         24
# ...

# %%
dirs = os.listdir('dataTweet')
i = 0
for a in dirs:
    dirs[i]='dataTweet/'+a
    i = i+1
dirs
# Out:
# ['dataTweet/#CopaAmericaDf.csv',
#  'dataTweet/#EURO2020Df.csv',
#  'dataTweet/#FreeBritneyDf.csv',
#  'dataTweet/#PrimeroLaTriDf.csv',
#  'dataTweet/AlemaniaDf.csv',
#  'dataTweet/AlfaroDf.csv',
#  'dataTweet/Angelo PreciadoDf.csv',
#  'dataTweet/ArboledaDf.csv',
#  'dataTweet/ArreagaDf.csv',
#  'dataTweet/BrazilDf.csv',
#  'dataTweet/CampanaDf.csv',
#  'dataTweet/CuevaDf.csv',
#  'dataTweet/dfTendenciasEc.csv',
#  'dataTweet/DíazDf.csv',
#  'dataTweet/El VARDf.csv',
#  'dataTweet/En 5Df.csv',
#  'dataTweet/EstradaDf.csv',
#  'dataTweet/FidelDf.csv',
#  'dataTweet/FranciaDf.csv',
#  'dataTweet/FrancoDf.csv',
#  'dataTweet/GalindezDf.csv',
#  'dataTweet/GarecaDf.csv',
#  'dataTweet/HincapiéDf.csv',
#  'dataTweet/HungríaDf.csv',
#  'dataTweet/Jordy CaicedoDf.csv',
#  'dataTweet/LapadulaDf.csv',
#  'dataTweet/MenaDf.csv',
#  'dataTweet/MendezDf.csv',
#  'dataTweet/NeymarDf.csv',
#  'dataTweet/NoboaDf.csv',
#  'dataTweet/PervisDf.csv',
#  'dataTweet/PerúDf.csv',
# ...

# %%
data = []
for a in dirs:
    x = pd.read_csv('dataTweet/' + a, sep=';', encoding='utf-8')
    print(x)
    data = pd.concat(data, x)
    
#data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-cdb5f755e1e0> in <module>
#       1 data = []
#       2 for a in dirs:
# ----> 3     x = pd.read_csv('dataTweet/' + a, sep=';', encoding='utf-8')
#       4     print(x)
#       5     data = pd.concat(data, x)
#
# ...

# %%
code = []
for j in range(len(dirs)):
    code.append("data"+ str(j+1) +" = pd.read_csv(dirs["+ str(j) +"], sep=';', encoding='utf-8');print(data"+ str(j+1)+")")
    print(code[j])
# Out:
# data1 = pd.read_csv(dirs[0], sep=';', encoding='utf-8');print(data1)
# data2 = pd.read_csv(dirs[1], sep=';', encoding='utf-8');print(data2)
# data3 = pd.read_csv(dirs[2], sep=';', encoding='utf-8');print(data3)
# data4 = pd.read_csv(dirs[3], sep=';', encoding='utf-8');print(data4)
# data5 = pd.read_csv(dirs[4], sep=';', encoding='utf-8');print(data5)
# data6 = pd.read_csv(dirs[5], sep=';', encoding='utf-8');print(data6)
# data7 = pd.read_csv(dirs[6], sep=';', encoding='utf-8');print(data7)
# data8 = pd.read_csv(dirs[7], sep=';', encoding='utf-8');print(data8)
# data9 = pd.read_csv(dirs[8], sep=';', encoding='utf-8');print(data9)
# data10 = pd.read_csv(dirs[9], sep=';', encoding='utf-8');print(data10)
# data11 = pd.read_csv(dirs[10], sep=';', encoding='utf-8');print(data11)
# data12 = pd.read_csv(dirs[11], sep=';', encoding='utf-8');print(data12)
# data13 = pd.read_csv(dirs[12], sep=';', encoding='utf-8');print(data13)
# ...

# %%
data1 = pd.read_csv(dirs[0], sep=';', encoding='utf-8');print(data1)
data2 = pd.read_csv(dirs[1], sep=';', encoding='utf-8');print(data2)
data3 = pd.read_csv(dirs[2], sep=';', encoding='utf-8');print(data3)
data4 = pd.read_csv(dirs[3], sep=';', encoding='utf-8');print(data4)
data5 = pd.read_csv(dirs[4], sep=';', encoding='utf-8');print(data5)
data6 = pd.read_csv(dirs[5], sep=';', encoding='utf-8');print(data6)
data7 = pd.read_csv(dirs[6], sep=';', encoding='utf-8');print(data7)
data8 = pd.read_csv(dirs[7], sep=';', encoding='utf-8');print(data8)
data9 = pd.read_csv(dirs[8], sep=';', encoding='utf-8');print(data9)
data10 = pd.read_csv(dirs[9], sep=';', encoding='utf-8');print(data10)
data11 = pd.read_csv(dirs[10], sep=';', encoding='utf-8');print(data11)
data12 = pd.read_csv(dirs[11], sep=';', encoding='utf-8');print(data12)
data13 = pd.read_csv(dirs[12], sep=';', encoding='utf-8');print(data13)
data14 = pd.read_csv(dirs[13], sep=';', encoding='utf-8');print(data14)
data15 = pd.read_csv(dirs[14], sep=';', encoding='utf-8');print(data15)
data16 = pd.read_csv(dirs[15], sep=';', encoding='utf-8');print(data16)
data17 = pd.read_csv(dirs[16], sep=';', encoding='utf-8');print(data17)
data18 = pd.read_csv(dirs[17], sep=';', encoding='utf-8');print(data18)
data19 = pd.read_csv(dirs[18], sep=';', encoding='utf-8');print(data19)
data20 = pd.read_csv(dirs[19], sep=';', encoding='utf-8');print(data20)
data21 = pd.read_csv(dirs[20], sep=';', encoding='utf-8');print(data21)
data22 = pd.read_csv(dirs[21], sep=';', encoding='utf-8');print(data22)
data23 = pd.read_csv(dirs[22], sep=';', encoding='utf-8');print(data23)
data24 = pd.read_csv(dirs[23], sep=';', encoding='utf-8');print(data24)
data25 = pd.read_csv(dirs[24], sep=';', encoding='utf-8');print(data25)
data26 = pd.read_csv(dirs[25], sep=';', encoding='utf-8');print(data26)
data27 = pd.read_csv(dirs[26], sep=';', encoding='utf-8');print(data27)
data28 = pd.read_csv(dirs[27], sep=';', encoding='utf-8');print(data28)
data29 = pd.read_csv(dirs[28], sep=';', encoding='utf-8');print(data29)
data30 = pd.read_csv(dirs[29], sep=';', encoding='utf-8');print(data30)
data31 = pd.read_csv(dirs[30], sep=';', encoding='utf-8');print(data31)
data32 = pd.read_csv(dirs[31], sep=';', encoding='utf-8');print(data32)
data33 = pd.read_csv(dirs[32], sep=';', encoding='utf-8');print(data33)
data34 = pd.read_csv(dirs[33], sep=';', encoding='utf-8');print(data34)
data35 = pd.read_csv(dirs[34], sep=';', encoding='utf-8');print(data35)
data36 = pd.read_csv(dirs[35], sep=';', encoding='utf-8');print(data36)
data37 = pd.read_csv(dirs[36], sep=';', encoding='utf-8');print(data37)
data38 = pd.read_csv(dirs[37], sep=';', encoding='utf-8');print(data38)
data39 = pd.read_csv(dirs[38], sep=';', encoding='utf-8');print(data39)
data40 = pd.read_csv(dirs[39], sep=';', encoding='utf-8');print(data40)
# Out:
#     Unnamed: 0                fecha  \
# 0            1  2021-06-24 00:18:26
# 1            2  2021-06-23 23:04:58
# 2            3  2021-06-24 00:41:28
# 3            4  2021-06-24 00:21:02
# 4            5  2021-06-24 00:42:39
# 5            6  2021-06-23 18:17:57
# 6            7  2021-06-23 12:17:00
# 7            8  2021-06-22 03:01:14
# 8            9  2021-06-22 10:42:23
# 9           10  2021-06-22 03:30:14
# 10          11  2021-06-22 08:37:55
#
#                                                 texto  retweets  favoritos
# 0   #CopaAmérica 🏆\n\n¡QUÉ GOLAZO! Luis Díaz abrió...      1899       6708
# 1   ¡GOL Y ASISTENCIA! 🇵🇪\n\nGianluca Lapadula fue...      1714       8107
# 2   Hemos conseguido un empate importante que nos ...      1134       8419
# 3   🇨🇴 Y este gol de Luis Díaz (@FCFSeleccionCol) ...       659       3086
# 4   Que golaço do @LuisFDiaz19 #CopaAmerica 🤩😃 htt...       283       1237
# 5   ¡Regresa Yeferson Soteldo! Tras recuperarse sa...       495       1748
# ...
