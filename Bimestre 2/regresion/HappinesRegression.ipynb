# %% [markdown]
# # Análisis Global Happines Report Dataset
# ### Integrantes: Daniel Álvarez, Jorge Flores y Daniel Tinizaray
# ### Fecha: 04/07/2021

# %% [markdown]
# ### Descripción:
# El dataset contiene la información a modo de reporte del estado de felicida global, estos datos son provistos por Gallup World Poll, estos datos han sido almacenados y son un reporte desde el año 2005 hasta el año 2020. Estos datos comprenden varios datos, como son los nombres de los paises, años de los datos comprendidos

# %% [markdown]
# # EDA al dataset Global Happines Report Dataset

# %%
import pandas as pd 
import plotly.express as px
deda = pd.read_csv('../proyect/kaggle_dataset/world-happiness-report.csv')

# %%
deda = deda.rename(columns={'Country name': 'country_name',\
                  'Log GDP per capita': 'gdp_per_capita',\
                  'Life Ladder':'life_Ladder',\
                   'Healthy life expectancy at birth':'healthy_life_expectancy_at_birth',\
                   'Social support':'social_supp', \
                   'Positive affect':'postve_affect', 'Negative affect':'negtve_affect',\
                   'Freedom to make life choices':'freedom_to_make_life_choices',\
                   'Perceptions of corruption': 'percept_of_corruption'
                  })

# %%
deda
# Out:
#      country_name  year  life_Ladder  gdp_per_capita  social_supp  \
# 0     Afghanistan  2008        3.724           7.370        0.451
# 1     Afghanistan  2009        4.402           7.540        0.552
# 2     Afghanistan  2010        4.758           7.647        0.539
# 3     Afghanistan  2011        3.832           7.620        0.521
# 4     Afghanistan  2012        3.783           7.705        0.521
# ...           ...   ...          ...             ...          ...
# 1944     Zimbabwe  2016        3.735           7.984        0.768
# 1945     Zimbabwe  2017        3.638           8.016        0.754
# 1946     Zimbabwe  2018        3.616           8.049        0.775
# 1947     Zimbabwe  2019        2.694           7.950        0.759
# 1948     Zimbabwe  2020        3.160           7.829        0.717
#
#       healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# 0                                50.80                         0.718
# ...

# %% [markdown]
# #### Tipos de valores de las columnas

# %%
deda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   country_name                      1949 non-null   object
#  1   year                              1949 non-null   int64
#  2   life_Ladder                       1949 non-null   float64
#  3   gdp_per_capita                    1913 non-null   float64
#  4   social_supp                       1936 non-null   float64
#  5   healthy_life_expectancy_at_birth  1894 non-null   float64
#  6   freedom_to_make_life_choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   percept_of_corruption             1839 non-null   float64
#  9   postve_affect                     1927 non-null   float64
#  10  negtve_affect                     1933 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %% [markdown]
# #### Filas de valores nulos para revisar

# %%
deda_null = deda[deda.Generosity.isnull()]
deda_null
# Out:
#      country_name  year  life_Ladder  gdp_per_capita  social_supp  \
# 28        Algeria  2014        6.355           9.335        0.818
# 29        Algeria  2016        5.341           9.362        0.749
# 66      Australia  2005        7.341          10.659        0.968
# 110       Bahrain  2012        5.027          10.716        0.911
# 111       Bahrain  2013        6.690          10.757        0.884
# ...           ...   ...          ...             ...          ...
# 1892    Venezuela  2019        5.081             NaN        0.888
# 1893    Venezuela  2020        4.574             NaN        0.805
# 1905      Vietnam  2017        5.175           8.876          NaN
# 1918        Yemen  2018        3.058             NaN        0.789
# 1919        Yemen  2019        4.197             NaN        0.870
#
#       healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# 28                               65.14                           NaN
# ...

# %% [markdown]
# #### Valores en las columnas del dataset que representan datos No nulos

# %%
deda.count()
# Out:
# country_name                        1949
# year                                1949
# life_Ladder                         1949
# gdp_per_capita                      1913
# social_supp                         1936
# healthy_life_expectancy_at_birth    1894
# freedom_to_make_life_choices        1917
# Generosity                          1860
# percept_of_corruption               1839
# postve_affect                       1927
# negtve_affect                       1933
# dtype: int64

# %%
deda.dropna(inplace=True)

# %%
d1 = deda['gdp_per_capita']
d1
# Out:
# 0       7.370
# 1       7.540
# 2       7.647
# 3       7.620
# 4       7.705
#         ...
# 1944    7.984
# 1945    8.016
# 1946    8.049
# 1947    7.950
# 1948    7.829
# Name: gdp_per_capita, Length: 1708, dtype: float64

# %%
df_regre = pd.DataFrame({'gdp_per_capita': deda['gdp_per_capita'],\
                  'life_Ladder': deda['life_Ladder'],\
                   'healthy_life_expectancy_at_birth':deda['healthy_life_expectancy_at_birth'],\
                   'social_supp ':deda['social_supp'], \
                   'postve_affect':deda['postve_affect'], 'negtve_affect':deda['negtve_affect'],\
                   'freedom_to_make_life_choices':deda['freedom_to_make_life_choices'],\
                   'percept_of_corruption': deda['percept_of_corruption']})
df_regre
# Out:
#       gdp_per_capita  life_Ladder  healthy_life_expectancy_at_birth  \
# 0              7.370        3.724                             50.80
# 1              7.540        4.402                             51.20
# 2              7.647        4.758                             51.60
# 3              7.620        3.832                             51.92
# 4              7.705        3.783                             52.24
# ...              ...          ...                               ...
# 1944           7.984        3.735                             54.40
# 1945           8.016        3.638                             55.00
# 1946           8.049        3.616                             55.60
# 1947           7.950        2.694                             56.20
# 1948           7.829        3.160                             56.80
#
#       social_supp   postve_affect  negtve_affect  \
# 0            0.451          0.518          0.258
# ...

# %%
fig = px.bar(deda, x='year', y='Generosity')
fig.show()
# Out:
# <div>                            <div id="d480351d-0802-46ae-a05a-55200fbcd5b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d480351d-0802-46ae-a05a-55200fbcd5b8")) {                    Plotly.newPlot(                        "d480351d-0802-46ae-a05a-55200fbcd5b8",                        [{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>Generosity=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2007,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2011,2012,2017,2018,2019,2011,2012,2013,2014,2006,2007,2008,2009,2010,2011,2012,20
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure([go.Bar(x=deda['country_name'], y=deda['postve_affect'])])
fig.show()
# Out:
# <div>                            <div id="5a9d02d4-5944-416c-b5fb-d1c4c7775799" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a9d02d4-5944-416c-b5fb-d1c4c7775799")) {                    Plotly.newPlot(                        "5a9d02d4-5944-416c-b5fb-d1c4c7775799",                        [{"type":"bar","x":["Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Algeria","Algeria","Algeria","Algeria","Algeria","Angola","Angola","Angola","Angola","Argentina","Argentina","Argentina","Argentina","Argentina","Arg
# ...

# %%
fig2 = go.Figure([go.Bar(x=deda['country_name'], y=deda['negtve_affect'])])
fig2.show()
# Out:
# <div>                            <div id="fd49a37f-bd5a-4203-8059-d208ebaaf4c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd49a37f-bd5a-4203-8059-d208ebaaf4c7")) {                    Plotly.newPlot(                        "fd49a37f-bd5a-4203-8059-d208ebaaf4c7",                        [{"type":"bar","x":["Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Algeria","Algeria","Algeria","Algeria","Algeria","Angola","Angola","Angola","Angola","Argentina","Argentina","Argentina","Argentina","Argentina","Arg
# ...

# %% [markdown]
# ## Análisis de regresión

# %%
import numpy as np
from sklearn.model_selection import train_test_split as tts

# %%
# aplicar vif par ver que variable predecir
df = pd.read_csv('../proyect/kaggle_dataset/world-happiness-report.csv')
df = df.rename(columns={'Country name': 'country_name',\
                  'Log GDP per capita': 'log_GDP_per_capita',\
                  'Life Ladder':'life_Ladder',\
                   'Healthy life expectancy at birth':'healthy_life_expectancy_at_birth',\
                   'Social support':'social_support', \
                   'Positive affect':'positive_affect', 'Negative affect':'negative_affect',\
                   'Freedom to make life choices':'freedom_to_make_life_choices',\
                   'Perceptions of corruption': 'perceptions_of_corruption'
                  })
df
# Out:
#      country_name  year  life_Ladder  log_GDP_per_capita  social_support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# ...

# %%
df = df.drop(columns=['country_name','year'])
df
# Out:
#       life_Ladder  log_GDP_per_capita  social_support  \
# 0           3.724               7.370           0.451
# 1           4.402               7.540           0.552
# 2           4.758               7.647           0.539
# 3           3.832               7.620           0.521
# 4           3.783               7.705           0.521
# ...           ...                 ...             ...
# 1944        3.735               7.984           0.768
# 1945        3.638               8.016           0.754
# 1946        3.616               8.049           0.775
# 1947        2.694               7.950           0.759
# 1948        3.160               7.829           0.717
#
#       healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# 0                                50.80                         0.718
# 1                                51.20                         0.679
# 2                                51.60                         0.600
# ...

# %%
df.dropna(inplace= True)

# %%
df.shape # sin NaN
# Out:
# (1708, 9)

# %%
df.shape
# Out:
# (1708, 9)

# %%
corrMatrixM = df.corr()
corrMatrixM.columns
print(corrMatrixM.log_GDP_per_capita.sort_values(axis=0, ascending=True))
# Out:
# perceptions_of_corruption          -0.343468
# negative_affect                    -0.224806
# Generosity                         -0.024565
# positive_affect                     0.296473
# freedom_to_make_life_choices        0.353182
# social_support                      0.705972
# life_Ladder                         0.792848
# healthy_life_expectancy_at_birth    0.860345
# log_GDP_per_capita                  1.000000
# Name: log_GDP_per_capita, dtype: float64

# %%
corrMatrixM.columns
# Out:
# Index(['life_Ladder', 'log_GDP_per_capita', 'social_support',
#        'healthy_life_expectancy_at_birth', 'freedom_to_make_life_choices',
#        'Generosity', 'perceptions_of_corruption', 'positive_affect',
#        'negative_affect'],
#       dtype='object')

# %% [markdown]
# ### VIF
# -  la variable con el VIF más alto podría ser un candidato potencial para la variable independiente.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vifF1 = pd.DataFrame()
vifF1["features"] = df.columns
vifF1["vif_Factor"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
print(vifF1)
# Out:
#                            features  vif_Factor
# 0                       life_Ladder   94.489024
# 1                log_GDP_per_capita  338.991567
# 2                    social_support  125.033373
# 3  healthy_life_expectancy_at_birth  284.457317
# 4      freedom_to_make_life_choices   53.294929
# 5                        Generosity    1.302064
# 6         perceptions_of_corruption   22.104630
# 7                   positive_affect   80.140405
# 8                   negative_affect   13.964990

# %%
df1 = df.drop(columns='log_GDP_per_capita')
# df
vifF2 = pd.DataFrame()
vifF2["features"] = df1.columns
vifF2["vif_Factor"] = [variance_inflation_factor(df1.values, i) for i in range(df1.shape[1])]
print(vifF2)
# Out:
#                            features  vif_Factor
# 0                       life_Ladder   87.420583
# 1                    social_support  109.722424
# 2  healthy_life_expectancy_at_birth  145.307676
# 3      freedom_to_make_life_choices   53.293549
# 4                        Generosity    1.277309
# 5         perceptions_of_corruption   22.047100
# 6                   positive_affect   79.905908
# 7                   negative_affect   13.831208

# %%
df1 = df1.drop(columns=['healthy_life_expectancy_at_birth','social_support','life_Ladder','positive_affect'])
# df
vifF3 = pd.DataFrame()
vifF3["features"] = df1.columns
vifF3["vif_Factor"] = [variance_inflation_factor(df1.values, i) for i in range(df1.shape[1])]
print(vifF3)
# Out:
#                        features  vif_Factor
# 0  freedom_to_make_life_choices    9.601923
# 1                    Generosity    1.142140
# 2     perceptions_of_corruption   13.296585
# 3               negative_affect   11.133513

# %%
df1 = df1.drop(columns='perceptions_of_corruption')

vifF4 = pd.DataFrame()
vifF4["features"] = df1.columns
vifF4["vif_Factor"] = [variance_inflation_factor(df1.values, i) for i in range(df1.shape[1])]
print(vifF4)
# Out:
#                        features  vif_Factor
# 0  freedom_to_make_life_choices    7.152547
# 1                    Generosity    1.055444
# 2               negative_affect    7.135587

# %%
df1.columns
# Out:
# Index(['freedom_to_make_life_choices', 'Generosity', 'negative_affect'], dtype='object')

# %%
df.columns
# Out:
# Index(['life_Ladder', 'log_GDP_per_capita', 'social_support',
#        'healthy_life_expectancy_at_birth', 'freedom_to_make_life_choices',
#        'Generosity', 'perceptions_of_corruption', 'positive_affect',
#        'negative_affect'],
#       dtype='object')

# %%
x_new = df.drop(['life_Ladder', 'social_support','healthy_life_expectancy_at_birth',
       'perceptions_of_corruption', 'positive_affect'], axis=1)
x_new.shape
# Out:
# (1708, 4)

# %%
y = df.log_GDP_per_capita 
y.shape
# Out:
# (1708,)

# %%
from sklearn.model_selection import train_test_split as tts
# 80% de las observaciones quedan para el conjunto de entrenamiento y 20% para el conjunto de prueba:
x_ent, x_test, y_ent, y_test = tts(x_new, y, train_size=0.8, random_state=42, shuffle=True)
print(x_ent.shape, x_test.shape)
# Out:
# (1366, 4) (342, 4)

# %%
from sklearn.linear_model import LinearRegression #Regresión Lineal con scikit-learn
 
regresion_lineal = LinearRegression()

# %%
# Crear una instancia y entrenar el modelo con los conjuntos de datos de entrenamiento:
lmI = LinearRegression()
lmI.fit(x_ent, y_ent)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
# Coeficientes de la función de regresión:
print('a = ' + str(lmI.intercept_) , 'y  B = ' + str(lmI.coef_) )

# Utilizar el modelo para generar las predicciones:

y_predict = lmI.predict(x_test)

# Verificar el R^2 (sobre el conjunto de test):

print(40*'*')
print('Coeficiente R^2: ', lmI.score(x_test, y_test)) 
print(40*'*')


# Calculamos el Error Cuadrático Medio (MSE = Mean Squared Error)
mse = mean_squared_error(y_true = y_test, y_pred = y_predict)

# La raíz cuadrada del MSE es el RMSE
rmse = np.sqrt(mse)
print('Error Cuadrático Medio (MSE) = ' + str(mse))
print('Raíz del Error Cuadrático Medio (RMSE) = ' + str(rmse))

# Visualización valores reales vs predichos por el modelo de regresión:

pd.Series(y_test.tolist()).plot(color='steelblue')
pd.Series(y_predict.tolist()).plot(marker="o", linewidth=0, color='black')
# Out:
# a = -1.7763568394002505e-15 y  B = [1.00000000e+00 1.19642005e-16 5.83824538e-17 3.07115717e-17]
# ****************************************
# Coeficiente R^2:  1.0
# ****************************************
# Error Cuadrático Medio (MSE) = 0.0
# Raíz del Error Cuadrático Medio (RMSE) = 0.0
# <AxesSubplot:>
