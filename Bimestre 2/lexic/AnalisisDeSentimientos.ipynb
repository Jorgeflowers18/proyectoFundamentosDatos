# %% [markdown]
# # Resultados del análisis de lenguaje natural
# ## Análisis del idioma, polaridad y subjetividad

# %% [markdown]
# # Carga del dataset

# %%
import pandas

df = pandas.read_csv('TweetsTrendingEc-8Julio21conNLP.csv', sep = ';')
df
# Out:
#      Unnamed: 0  Unnamed: 0.1                fecha  \
# 0             0             1  2021-07-07 19:22:13
# 1             1             2  2021-07-08 05:57:28
# 2             2             3  2021-07-08 09:05:40
# 3             3             4  2021-07-08 05:47:18
# 4             4             5  2021-07-08 02:40:00
# ..          ...           ...                  ...
# 533         533            14  2021-07-04 18:35:29
# 534         534            15  2021-07-08 17:15:56
# 535         535             1  2021-07-08 16:38:59
# 536         536             2  2021-07-08 16:12:02
# 537         537             3  2021-07-08 16:25:43
#
#                                                  texto  retweets  favoritos  \
# 0    Tuliwaambia wamejazama CCM bungeni hakuna kitu...       201       1177
# 1    "There’s no reason for me to be President when...        67        367
# 2    Nadhani sasa kila mmoja amerudi kwenye factory...        77        642
# ...

# %% [markdown]
# ### Eliminamos aquellos registros que carecen de polaridad o subjetividad que analizar

# %%
# Creamos la condición
df = df[df.polaridad != 0]
df = df[df.subjetividad != 0]
df
# Out:
#      Unnamed: 0  Unnamed: 0.1                fecha  \
# 1             1             2  2021-07-08 05:57:28
# 3             3             4  2021-07-08 05:47:18
# 5             5             6  2021-07-08 15:27:53
# 6             6             7  2021-07-06 19:15:14
# 44           44             1  2021-07-07 18:53:40
# ..          ...           ...                  ...
# 428         428             9  2021-07-07 23:33:06
# 429         429            10  2021-07-08 13:52:14
# 431         431            12  2021-07-03 15:08:22
# 437         437             3  2021-07-08 17:50:03
# 438         438             4  2021-07-08 16:05:50
#
#                                                  texto  retweets  favoritos  \
# 1    "There’s no reason for me to be President when...        67        367
# 3    "In other countries you have kickbacks of 10%....        17         97
# 5    #TBT early this year in #Tanzania - “invention...        29        126
# ...

# %%
df.groupby('topic').nunique()
# Out:
#                       Unnamed: 0  Unnamed: 0.1  fecha  texto  retweets  \
# topic
# #HappyBirthdayToARMY           3             3      3      3         3
# #MorenoDebeResponder           1             1      1      1         1
# Banco                          1             1      1      1         1
# Bicentenario                   2             2      2      2         2
# Dubai                          9             9      9      9         9
# Enserio                        2             2      2      2         2
# Freezer                        8             8      8      8         8
# IESS                           4             4      4      4         4
# Kitu                           4             4      4      4         4
# Loja                           1             1      1      1         1
# López                          2             2      2      2         2
# Pfizer                         1             1      1      1         1
# ...

# %% [markdown]
# ### Comparamos aquellos tweets con mayor y menor polaridad
#
# La polaridad es un valor flotante que se encuentra en el rango [-1.0, 1.0]

# %%
porPolaridadInversa = df.sort_values('polaridad', ascending = False)    # Textos mas cercanos a una opinión positiva
porPolaridadInversa.head(20)
# Out:
#      Unnamed: 0  Unnamed: 0.1                fecha  \
# 253         253            12  2021-07-07 19:51:24
# 295         295            14  2021-07-08 10:25:48
# 110         110             1  2021-07-07 02:00:05
# 113         113             4  2021-07-06 16:24:33
# 320         320            10  2021-06-30 16:55:00
# 48           48             5  2021-07-05 13:09:07
# 427         427             8  2021-07-08 17:15:31
# 220         220             8  2021-07-08 12:27:08
# 315         315             5  2021-07-08 16:44:51
# 119         119            10  2021-07-08 13:02:38
# 360         360             4  2021-07-08 16:39:02
# 217         217             5  2021-07-07 20:10:32
# 425         425             6  2021-07-08 14:05:05
# 318         318             8  2021-07-03 02:49:43
# 111         111             2  2021-07-07 15:59:31
# 6             6             7  2021-07-06 19:15:14
# 359         359             3  2021-07-08 15:55:35
# ...

# %%
porPolaridad = df.sort_values('polaridad', ascending = True)    # Textos mas cercanos a una opinión negativa
porPolaridad.head(20)
# Out:
#      Unnamed: 0  Unnamed: 0.1                fecha  \
# 331         331            11  2021-07-07 23:11:28
# 121         121            12  2021-07-07 15:44:04
# 431         431            12  2021-07-03 15:08:22
# 371         371             5  2021-07-07 20:27:35
# 341         341             6  2021-07-07 10:00:02
# 1             1             2  2021-07-08 05:57:28
# 365         365             2  2021-07-08 02:30:44
# 397         397             4  2021-07-08 15:50:45
# 216         216             4  2021-07-07 20:23:13
# 358         358             2  2021-07-08 15:26:21
# 378         378            12  2021-07-08 13:30:16
# 221         221             9  2021-07-08 05:31:08
# 3             3             4  2021-07-08 05:47:18
# 226         226            14  2021-07-08 09:09:09
# 173         173             5  2021-07-08 17:37:32
# 176         176             8  2021-07-08 02:42:24
# 391         391            10  2021-07-02 15:00:00
# ...

# %% [markdown]
# ### Tweets con mayor subjetividad
# La subjetividad es un valor flotante comprendido en el rango [0.0, 1.0] donde 0.0 es muy objetivo (definición) y 1.0 es muy subjetivo (opinición personal).

# %%
porSubjetividad = df.sort_values('subjetividad', ascending = False) # Textos más cercanos a una definición
porSubjetividad.head(20)
# Out:
#      Unnamed: 0  Unnamed: 0.1                fecha  \
# 1             1             2  2021-07-08 05:57:28
# 121         121            12  2021-07-07 15:44:04
# 6             6             7  2021-07-06 19:15:14
# 308         308            12  2021-07-07 01:49:51
# 298         298             2  2021-07-08 15:38:58
# 51           51             2  2021-07-07 21:30:21
# 331         331            11  2021-07-07 23:11:28
# 253         253            12  2021-07-07 19:51:24
# 365         365             2  2021-07-08 02:30:44
# 318         318             8  2021-07-03 02:49:43
# 397         397             4  2021-07-08 15:50:45
# 431         431            12  2021-07-03 15:08:22
# 124         124            15  2021-07-07 02:30:33
# 295         295            14  2021-07-08 10:25:48
# 371         371             5  2021-07-07 20:27:35
# 111         111             2  2021-07-07 15:59:31
# 428         428             9  2021-07-07 23:33:06
# ...

# %%
porSubjetividadInversa = df.sort_values('subjetividad', ascending = True)   # Textos mas cercanos a una opinión personal
porSubjetividadInversa.head(20)
# Out:
#      Unnamed: 0  Unnamed: 0.1                fecha  \
# 438         438             4  2021-07-08 16:05:50
# 411         411             9  2021-07-01 00:01:24
# 408         408             6  2021-07-08 01:19:02
# 405         405             3  2021-07-08 02:33:25
# 437         437             3  2021-07-08 17:50:03
# 169         169             1  2021-07-07 13:48:53
# 346         346             3  2021-07-07 18:51:00
# 123         123            14  2021-07-08 00:00:00
# 429         429            10  2021-07-08 13:52:14
# 392         392            11  2021-07-06 15:38:17
# 70           70             6  2021-07-06 22:55:01
# 382         382             1  2021-07-07 16:50:51
# 176         176             8  2021-07-08 02:42:24
# 173         173             5  2021-07-08 17:37:32
# 391         391            10  2021-07-02 15:00:00
# 283         283             2  2021-07-07 10:19:24
# 221         221             9  2021-07-08 05:31:08
# ...

# %% [markdown]
# ## Gráficas
# La columna subjetividad está comprendida en el rango [0 to 1], donde 1 representa a un tweet más cercano a una opinión personal mientras que su valor contrario hace referencia a un texto mas objetivo, cercano a una definición.
#
# La columna polaridad está comprendida en el rango [1 to -1], donde los valores cercanos a 1 representan una opinión positiva mientras que el otro extremo una posición negativa.

# %%
import matplotlib.pyplot as plt 

subjetividad = df['subjetividad']
polaridad = df['polaridad']

data = [subjetividad, polaridad]

plt.boxplot(data)
plt.title("Subjetividad/objetividad vs Polaridad")
plt.show()
