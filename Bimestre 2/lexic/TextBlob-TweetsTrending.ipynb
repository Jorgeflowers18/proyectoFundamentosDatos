# %%
from textblob import TextBlob
import pandas

# %% [markdown]
# ## Carga de datos del DF

# %%
df = pandas.read_csv("TweetsTrendingEc-8Julio21conNLP.csv", delimiter = ';')

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1                fecha  \
# 0             0             1  2021-07-07 19:22:13
# 1             1             2  2021-07-08 05:57:28
# 2             2             3  2021-07-08 09:05:40
# 3             3             4  2021-07-08 05:47:18
# 4             4             5  2021-07-08 02:40:00
# ..          ...           ...                  ...
# 533         533            14  2021-07-04 18:35:29
# 534         534            15  2021-07-08 17:15:56
# 535         535             1  2021-07-08 16:38:59
# 536         536             2  2021-07-08 16:12:02
# 537         537             3  2021-07-08 16:25:43
#
#                                                  texto  retweets  favoritos  \
# 0    Tuliwaambia wamejazama CCM bungeni hakuna kitu...       201       1177
# 1    "There’s no reason for me to be President when...        67        367
# 2    Nadhani sasa kila mmoja amerudi kwenye factory...        77        642
# ...

# %% [markdown]
# ## Detección del idioma e inserción del resultado en una nueva columna del df
#
# ## Advertencia sobre el límite de uso de Google Cloud
# > No se deben realizar demasiadas peticiones al mismo tiempo, se recomienda establecer una espera entre cada petición para evitar el HTTP Error 429: Too Many Requests.

# %%
import time

# Creamos nuevas columnas
df = df.assign( idioma = "" )
df = df.assign( polaridad = "" )
df = df.assign( subjetividad = "" )

index = 0
print('Tamaño del df: ' , df.shape)

for texto in df['texto']:
    # Impresión del índice que estamos tratando
    print(index , '\n')
    
    tweet = TextBlob(texto)
    
    # Detección del idioma
    idiomaDetectado = tweet.detect_language()
    
    # Detección de la polaridad
    polaridad = tweet.sentiment.polarity
    
    # Detección de la subjetividad
    subjetividad = tweet.sentiment.subjectivity
    
    print('Language: ' , idiomaDetectado , ' Polaridad: ' , polaridad , ' Subjetividad: ' , subjetividad , ': \n' , texto)
    
    # Guardamos los resultados
    df.loc[index, 'idioma'] = idiomaDetectado
    df.loc[index, 'polaridad'] = polaridad
    df.loc[index, 'subjetividad'] = subjetividad
    
    # Pasamos a la siguiente fila
    index = index + 1
    
    time.sleep(1)
# Out:
# Tamaño del df:  (538, 13)
# 0
#
# Language:  sw  Polaridad:  0.0  Subjetividad:  0.0 :
#  Tuliwaambia wamejazama CCM bungeni hakuna kitu cha maana watafanya! Haya mkeka huu hapa wa makati ya kutuma hela
#
# U… https://t.co/TX2lIWcYnk
# 1
#
# Language:  en  Polaridad:  -0.5  Subjetividad:  1.0 :
#  "There’s no reason for me to be President when we say that the corrupt shouldn't be punished. People who misuse pub… https://t.co/TgnC5TFa4k
# 2
#
# Language:  sw  Polaridad:  0.0  Subjetividad:  0.0 :
#  Nadhani sasa kila mmoja amerudi kwenye factory setting na kuachana na illusions na mauzauza
# 👉hakuna kitu kimebadil… https://t.co/UOhlf5W1HP
# 3
#
# Language:  en  Polaridad:  -0.125  Subjetividad:  0.375 :
#  "In other countries you have kickbacks of 10%. In Kenya people get to demand 20 to 100 per cent as kickbacks.
#
# We… https://t.co/qMksLPWZL1
# 4
#
# Language:  sw  Polaridad:  0.0  Subjetividad:  0.0 :
#  Kitu gani kinajiri ulipo ? Tufahamishane @VincentAteya @MelodySinzore1
#
# ...

# %%
df.groupby(['idioma']).count()
# Out:
#         Unnamed: 0  Unnamed: 0.1  fecha  texto  retweets  favoritos  hashtags  \
# idioma
# ar               3             3      3      3         3          3         3
# bn               1             1      1      1         1          1         1
# ca               1             1      1      1         1          1         1
# co               1             1      1      1         1          1         1
# en              84            84     84     84        84         84        84
# es             354           354    354    354       354        354       354
# fr               7             7      7      7         7          7         7
# gl               1             1      1      1         1          1         1
# id               2             2      2      2         2          2         2
# it               2             2      2      2         2          2         2
# ja               7             7      7      7         7          7         7
# ...

# %%
df.groupby(['polaridad']).count()
# Out:
#            Unnamed: 0  Unnamed: 0.1  fecha  texto  retweets  favoritos  \
# polaridad
# -0.875000           1             1      1      1         1          1
# -0.800000           1             1      1      1         1          1
# -0.600000           2             2      2      2         2          2
# -0.500000           1             1      1      1         1          1
# -0.500000           3             3      3      3         3          3
# -0.400000           1             1      1      1         1          1
# -0.250000           1             1      1      1         1          1
# -0.166667           1             1      1      1         1          1
# -0.145833           1             1      1      1         1          1
# -0.125000           2             2      2      2         2          2
# -0.100000           2             2      2      2         2          2
# -0.071429           1             1      1      1         1          1
# ...

# %%
df.groupby(['subjetividad']).count()
# Out:
#               Unnamed: 0  Unnamed: 0.1  fecha  texto  retweets  favoritos  \
# subjetividad
# 0.000000             454           454    454    454       454        454
# 0.066667               6             6      6      6         6          6
# 0.100000               4             4      4      4         4          4
# 0.125000               1             1      1      1         1          1
# 0.144444               1             1      1      1         1          1
# 0.200000               6             6      6      6         6          6
# 0.214286               1             1      1      1         1          1
# 0.227273               1             1      1      1         1          1
# 0.250000               1             1      1      1         1          1
# 0.270833               1             1      1      1         1          1
# 0.283333               1             1      1      1         1          1
# ...

# %% [markdown]
# ## Guardamos el resultado

# %%
nombreArchivo = "TweetsTrendingEc-8Julio21conNLP.csv"
df.to_csv(nombreArchivo, sep = ';')

# %%
df.shape[0]
# Out:
# 538

# %% [markdown]
# ## Análisis de ejemplo de una definición en español

# %%
intro = "Python es un lenguaje de programación interpretado cuya filosofía hace hincapié en la legibilidad de su código.2​ Se trata de un lenguaje de programación multiparadigma, ya que soporta parcialmente la orientación a objetos, programación imperativa y, en menor medida, programación funcional. Es un lenguaje interpretado, dinámico y multiplataforma. Es administrado por la Python Software Foundation. Posee una licencia de código abierto, denominada Python Software Foundation License."

# %%
wiki = TextBlob(intro)
wiki.detect_language()
# Out:
# 'es'

# %%
wiki.sentiment.polarity
# Out:
# 0.0

# %%
wiki.sentiment.subjectivity
# Out:
# 0.0

# %%
wiki.tags
# Out:
# [('Python', 'NNP'),
#  ('es', 'CC'),
#  ('un', 'JJ'),
#  ('lenguaje', 'NN'),
#  ('de', 'IN'),
#  ('programación', 'FW'),
#  ('interpretado', 'JJ'),
#  ('cuya', 'NN'),
#  ('filosofía', 'NN'),
#  ('hace', 'NN'),
#  ('hincapié', 'NN'),
#  ('en', 'IN'),
#  ('la', 'FW'),
#  ('legibilidad', 'FW'),
#  ('de', 'FW'),
#  ('su', 'FW'),
#  ('código.2\u200b', 'FW'),
#  ('Se', 'NNP'),
#  ('trata', 'NN'),
#  ('de', 'FW'),
#  ('un', 'FW'),
#  ('lenguaje', 'FW'),
#  ('de', 'FW'),
#  ('programación', 'FW'),
#  ('multiparadigma', 'NN'),
#  ('ya', 'PRP'),
#  ('que', 'VBP'),
#  ('soporta', 'JJ'),
#  ('parcialmente', 'NN'),
#  ('la', 'NN'),
#  ('orientación', 'IN'),
#  ('a', 'DT'),
#  ('objetos', 'NN'),
#  ('programación', 'NN'),
#  ('imperativa', 'NN'),
#  ('y', 'NN'),
#  ('en', 'FW'),
#  ('menor', 'FW'),
#  ('medida', 'NN'),
#  ('programación', 'JJ'),
#  ('funcional', 'NN'),
#  ('Es', 'NNP'),
#  ('un', 'JJ'),
#  ('lenguaje', 'NN'),
#  ('interpretado', 'NN'),
#  ('dinámico', 'NN'),
#  ('y', 'NN'),
# ...

# %% [markdown]
# ## Etiquetas y su significado
#
# - CC coordinating conjunction
# - CD cardinal digit
# - DT determiner
# - EX existential there (like: “there is” … think of it like “there exists”)
# - FW foreign word
# - IN preposition/subordinating conjunction
# - JJ adjective ‘big’
# - JJR adjective, comparative ‘bigger’
# - JJS adjective, superlative ‘biggest’
# - LS list marker 1)
# - MD modal could, will
# - NN noun, singular ‘desk’
# - NNS noun plural ‘desks’
# - NNP proper noun, singular ‘Harrison’
# - NNPS proper noun, plural ‘Americans’
# - PDT predeterminer ‘all the kids’
# - POS possessive ending parent‘s
# - PRP personal pronoun I, he, she
# - PRP<dolar>  possessive pronoun my, his, hers
# - RB adverb very, silently,
# - RBR adverb, comparative better
# - RBS adverb, superlative best
# - RP particle give up
# - TO to go ‘to‘ the store.
# - UH interjection errrrrrrrm
# - VB verb, base form take
# - VBD verb, past tense took
# - VBG verb, gerund/present participle taking
# - VBN verb, past participle taken
# - VBP verb, sing. present, non-3d take
# - VBZ verb, 3rd person sing. present takes
# - WDT wh-determiner which
# - WP wh-pronoun who, what
# - WP$ possessive wh-pronoun whose
# - WRB wh-abverb where, when

# %%
wiki.noun_phrases
# Out:
# WordList(['python', 'es un lenguaje', 'programación interpretado cuya filosofía hace hincapié', 'su código.2\u200b', 'se', 'un lenguaje', 'programación multiparadigma', 'ya que soporta parcialmente', 'programación imperativa y', 'menor medida', 'programación funcional', 'es', 'un lenguaje interpretado', 'dinámico y multiplataforma', 'es', 'administrado por', 'python software', 'posee', 'una licencia', 'código abierto', 'python software', 'license'])

# %% [markdown]
# ## Análisis de ejemplo de un texto en ingles

# %%
text = '''
The titular threat of The Blob has always struck me as the ultimate movie
monster: an insatiably hungry, amoeba-like mass able to penetrate
virtually any safeguard, capable of--as a doomed doctor chillingly
describes it--"assimilating flesh on contact.
Snide comparisons to gelatin be damned, it's a concept with the most
devastating of potential consequences, not unlike the grey goo scenario
proposed by technological theorists fearful of
artificial intelligence run rampant.
'''

# %%
blob = TextBlob(text)

# %%
blob.sentiment.subjectivity
# Out:
# 0.6931818181818182

# %%
blob.sentiment.polarity
# Out:
# -0.1590909090909091

# %%
blob.tags
# Out:
# [('The', 'DT'),
#  ('titular', 'JJ'),
#  ('threat', 'NN'),
#  ('of', 'IN'),
#  ('The', 'DT'),
#  ('Blob', 'NNP'),
#  ('has', 'VBZ'),
#  ('always', 'RB'),
#  ('struck', 'VBN'),
#  ('me', 'PRP'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('ultimate', 'JJ'),
#  ('movie', 'NN'),
#  ('monster', 'NN'),
#  ('an', 'DT'),
#  ('insatiably', 'RB'),
#  ('hungry', 'JJ'),
#  ('amoeba-like', 'JJ'),
#  ('mass', 'NN'),
#  ('able', 'JJ'),
#  ('to', 'TO'),
#  ('penetrate', 'VB'),
#  ('virtually', 'RB'),
#  ('any', 'DT'),
#  ('safeguard', 'NN'),
#  ('capable', 'JJ'),
#  ('of', 'IN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('doomed', 'JJ'),
#  ('doctor', 'NN'),
#  ('chillingly', 'RB'),
#  ('describes', 'VBZ'),
#  ('it', 'PRP'),
#  ('assimilating', 'VBG'),
#  ('flesh', 'NN'),
#  ('on', 'IN'),
#  ('contact', 'NN'),
#  ('Snide', 'JJ'),
#  ('comparisons', 'NNS'),
#  ('to', 'TO'),
#  ('gelatin', 'VB'),
#  ('be', 'VB'),
#  ('damned', 'VBN'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('a', 'DT'),
#  ('concept', 'NN'),
# ...

# %% [markdown]
# ## Análisis de sentimientos

# %%
for sentence in blob.sentences:
    print(sentence , '\n' , sentence.sentiment)
# Out:
# The titular threat of The Blob has always struck me as the ultimate movie
# monster: an insatiably hungry, amoeba-like mass able to penetrate
# virtually any safeguard, capable of--as a doomed doctor chillingly
# describes it--"assimilating flesh on contact.
#  Sentiment(polarity=0.06000000000000001, subjectivity=0.605)
# Snide comparisons to gelatin be damned, it's a concept with the most
# devastating of potential consequences, not unlike the grey goo scenario
# proposed by technological theorists fearful of
# artificial intelligence run rampant.
#  Sentiment(polarity=-0.34166666666666673, subjectivity=0.7666666666666666)
